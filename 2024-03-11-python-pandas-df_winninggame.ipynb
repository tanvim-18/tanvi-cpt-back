# %%
import seaborn as sns

# Load the titanic dataset
grade_data = sns.load_dataset('attention')

print("Grade Data")


print(grade_data.columns) # titanic data set
display(grade_data[['subject','attention', 'solutions', 'score',  ]])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_7423/795176599.py in <module>
# ----> 1 import seaborn as sns
#       2
#       3 # Load the titanic dataset
#       4 grade_data = sns.load_dataset('attention')
#       5
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
student = {
    'subject' : ['1'],
    'attention': ['focused'],
    'solutions': [2],
    'score': [8.0],
}
